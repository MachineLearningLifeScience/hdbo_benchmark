# %%
from create_table import create_base_table
from download_and_process_tables import compute_pmo_benchmark_table

n_dimensions = 2
tags: list[str] | None = None
df = create_base_table(
    n_dimensions=n_dimensions,
    save_cache=True,
    use_cache=True,
    tags=tags,
)

df = compute_pmo_benchmark_table(df, n_dimensions=n_dimensions, use_tex=False)

# %%
df
# Out:
#                           HillClimbing Hvarfner's VanillaBO  RandomLineBO  \
# Oracle
# albuterol_similarity       0.35 ± 0.13          0.43 ± 0.04   0.41 ± 0.03
# amlodipine_mpo             0.33 ± 0.01          0.35 ± 0.02   0.40 ± 0.05
# celecoxib_rediscovery      0.16 ± 0.06          0.15 ± 0.00   0.18 ± 0.05
# deco_hop                   0.52 ± 0.00          0.54 ± 0.00   0.54 ± 0.00
# drd2_docking               0.07 ± 0.06          0.07 ± 0.07   0.03 ± 0.00
# fexofenadine_mpo           0.20 ± 0.22          0.63 ± 0.02   0.66 ± 0.03
# gsk3_beta                  0.12 ± 0.04          0.28 ± 0.10   0.28 ± 0.07
# isomer_c7h8n2o2            0.56 ± 0.16          0.89 ± 0.01   0.83 ± 0.06
# isomer_c9h10n2o2pf2cl      0.47 ± 0.11          0.69 ± 0.07   0.58 ± 0.02
# jnk3                       0.10 ± 0.03          0.12 ± 0.05   0.13 ± 0.04
# median_1                   0.16 ± 0.01          0.16 ± 0.00   0.17 ± 0.03
# median_2                   0.11 ± 0.00          0.13 ± 0.00   0.14 ± 0.00
# ...
