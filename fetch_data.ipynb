# %%
import wandb 
import pandas as pd
from pathlib import Path
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

WANDB_PROJECT = "hdbo-embeddings-benchmark"
WANDB_ENTITY = "hdbo-benchmark"

matplotlib.rcParams.update({"text.usetex": True})
sns.set_theme(style="whitegrid", font_scale=1.75)

# %%
def get_all_runs_for_experiment(
    experiment_name: str,
    solver_name: str | None = None,
    function_name: str | None = None,
    n_dimensions: int | None = None,
    seed: int | None = None,
    tags: list[str] | None = None,
) -> list[wandb.apis.public.Run]:
    api = wandb.Api()

    filter_: dict[str, str | int | dict] = {
        "state": {"$in": ["finished", "running", "failed", "crashed"]},
    }
    if solver_name is not None:
        filter_["config.solver_name"] = solver_name

    if function_name is not None:
        filter_["config.function_name"] = function_name

    if n_dimensions is not None:
        # If it's a discrete solver, we don't need to filter by n_dimensions
        if solver_name in ["bounce", "pr"]:
            pass
        else:
            filter_["config.n_dimensions"] = n_dimensions

    if seed is not None:
        filter_["config.seed"] = seed

    if tags is not None:
        filter_["tags"] = {"$in": tags}

    runs = api.runs(
        f"{WANDB_ENTITY}/{experiment_name}",
        filter_ if filter_ else None,
    )
    return list(runs)

# %%
def convert_data_to_dataframes(
    all_data: list[wandb.apis.public.Run],
) -> list[pd.DataFrame]:
    dfs: list[pd.DataFrame] = []
    for i, run in enumerate(all_data):
        print(f"Processing run {i + 1}/{len(all_data)}")
        df = run.history()
        df["solver_name"] = run.config["solver_name"]
        df["function_name"] = run.config["function_name"]
        df["seed"] = run.config["seed"]
        df["poli_hash"] = run.config["poli_hash"]
        df["hdbo_benchmark_hash"] = run.config["hdbo_benchmark_hash"]
        df["poli_baselines_hash"] = run.config["poli_baselines_hash"]
        df["state"] = run.state
        dfs.append(df)

    return dfs


def create_base_table(
    n_dimensions: int = 128,
    save_cache: bool = True,
    use_cache: bool = False,
    tags: list[str] | None = None,
) -> pd.DataFrame:
    CACHE_PATH = Path("cache/results_cache")
    CACHE_PATH.mkdir(exist_ok=True, parents=True)
    tags_str = "-".join(tags) if tags is not None else "all"
    CACHE_FILE = (
        CACHE_PATH / f"base_table-n_dimensions-{n_dimensions}-tags-{tags_str}.csv"
    )

    if use_cache and CACHE_FILE.exists():
        df = pd.read_csv(CACHE_FILE)
        return df

    all_runs = get_all_runs_for_experiment(
        experiment_name="benchmark_on_pmo", n_dimensions=n_dimensions, tags=tags
    )

    # Append with the results from PR on 2D
    if n_dimensions != 2:
        pr_runs = get_all_runs_for_experiment(
            experiment_name="benchmark_on_pmo",
            solver_name="pr",
            n_dimensions=2,
            tags=tags,
        )
        all_runs.extend(pr_runs)

    # Append the results of Bounce on 128D
    if n_dimensions != 128:
        bounce_runs = get_all_runs_for_experiment(
            experiment_name="benchmark_on_pmo",
            solver_name="bounce",
            n_dimensions=128,
            tags=tags,
        )
        all_runs.extend(bounce_runs)

    all_dfs = convert_data_to_dataframes(all_runs)

    df = pd.concat(all_dfs)
    if save_cache:
        df.to_csv(CACHE_FILE, index=False)

    return df

if __name__ == "__main__":
    df = create_base_table(
        n_dimensions=2,
        save_cache=True,
        use_cache=False,
        tags=None,
    )
    print(df)
# Out:
# Processing run 1/1025
# Processing run 2/1025
# Processing run 3/1025
# Processing run 4/1025
# Processing run 5/1025
# Processing run 6/1025
# Processing run 7/1025
# Processing run 8/1025
# Processing run 9/1025
# Processing run 10/1025
# Processing run 11/1025
# Processing run 12/1025
# Processing run 13/1025
# Processing run 14/1025
# Processing run 15/1025
# Processing run 16/1025
# Processing run 17/1025
# Processing run 18/1025
# Processing run 19/1025
# Processing run 20/1025
# Processing run 21/1025
# Processing run 22/1025
# Processing run 23/1025
# Processing run 24/1025
# Processing run 25/1025
# Processing run 26/1025
# Processing run 27/1025
# Processing run 28/1025
# Processing run 29/1025
# Processing run 30/1025
# Processing run 31/1025
# Processing run 32/1025
# Processing run 33/1025
# Processing run 34/1025
# Processing run 35/1025
# Processing run 36/1025
# Processing run 37/1025
# Processing run 38/1025
# Processing run 39/1025
# Processing run 40/1025
# Processing run 41/1025
# Processing run 42/1025
# Processing run 43/1025
# Processing run 44/1025
# Processing run 45/1025
# Processing run 46/1025
# Processing run 47/1025
# Processing run 48/1025
# Processing run 49/1025
# Processing run 50/1025
# Processing run 51/1025
# Processing run 52/1025
# Processing run 53/1025
# Processing run 54/1025
# Processing run 55/1025
# Processing run 56/1025
# Processing run 57/1025
# Processing run 58/1025
# Processing run 59/1025
# Processing run 60/1025
# Processing run 61/1025
# Processing run 62/1025
# Processing run 63/1025
# Processing run 64/1025
# Processing run 65/1025
# Processing run 66/1025
# Processing run 67/1025
# Processing run 68/1025
# Processing run 69/1025
# Processing run 70/1025
# Processing run 71/1025
# Processing run 72/1025
# Processing run 73/1025
# Processing run 74/1025
# Processing run 75/1025
# Processing run 76/1025
# Processing run 77/1025
# Processing run 78/1025
# Processing run 79/1025
# Processing run 80/1025
# Processing run 81/1025
# Processing run 82/1025
# Processing run 83/1025
# Processing run 84/1025
# Processing run 85/1025
# Processing run 86/1025
# Processing run 87/1025
# Processing run 88/1025
# Processing run 89/1025
# Processing run 90/1025
# Processing run 91/1025
# Processing run 92/1025
# Processing run 93/1025
# Processing run 94/1025
# Processing run 95/1025
# Processing run 96/1025
# Processing run 97/1025
# Processing run 98/1025
# Processing run 99/1025
# Processing run 100/1025
# Processing run 101/1025
# Processing run 102/1025
# Processing run 103/1025
# Processing run 104/1025
# Processing run 105/1025
# Processing run 106/1025
# Processing run 107/1025
# Processing run 108/1025
# Processing run 109/1025
# Processing run 110/1025
# Processing run 111/1025
# Processing run 112/1025
# Processing run 113/1025
# Processing run 114/1025
# Processing run 115/1025
# Processing run 116/1025
# Processing run 117/1025
# Processing run 118/1025
# Processing run 119/1025
# Processing run 120/1025
# Processing run 121/1025
# Processing run 122/1025
# Processing run 123/1025
# Processing run 124/1025
# Processing run 125/1025
# Processing run 126/1025
# Processing run 127/1025
# Processing run 128/1025
# Processing run 129/1025
# Processing run 130/1025
# Processing run 131/1025
# Processing run 132/1025
# Processing run 133/1025
# Processing run 134/1025
# Processing run 135/1025
# Processing run 136/1025
# Processing run 137/1025
# Processing run 138/1025
# Processing run 139/1025
# Processing run 140/1025
# Processing run 141/1025
# Processing run 142/1025
# Processing run 143/1025
# Processing run 144/1025
# Processing run 145/1025
# Processing run 146/1025
# Processing run 147/1025
# Processing run 148/1025
# Processing run 149/1025
# Processing run 150/1025
# Processing run 151/1025
# Processing run 152/1025
# Processing run 153/1025
# Processing run 154/1025
# Processing run 155/1025
# Processing run 156/1025
# Processing run 157/1025
# Processing run 158/1025
# Processing run 159/1025
# Processing run 160/1025
# Processing run 161/1025
# Processing run 162/1025
# Processing run 163/1025
# Processing run 164/1025
# Processing run 165/1025
# Processing run 166/1025
# Processing run 167/1025
# Processing run 168/1025
# Processing run 169/1025
# Processing run 170/1025
# Processing run 171/1025
# Processing run 172/1025
# Processing run 173/1025
# Processing run 174/1025
# Processing run 175/1025
# Processing run 176/1025
# Processing run 177/1025
# Processing run 178/1025
# Processing run 179/1025
# Processing run 180/1025
# Processing run 181/1025
# Processing run 182/1025
# Processing run 183/1025
# Processing run 184/1025
# Processing run 185/1025
# Processing run 186/1025
# Processing run 187/1025
# Processing run 188/1025
# Processing run 189/1025
# Processing run 190/1025
# Processing run 191/1025
# Processing run 192/1025
# Processing run 193/1025
# Processing run 194/1025
# Processing run 195/1025
# Processing run 196/1025
# Processing run 197/1025
# Processing run 198/1025
# Processing run 199/1025
# Processing run 200/1025
# Processing run 201/1025
# Processing run 202/1025
# Processing run 203/1025
# Processing run 204/1025
# Processing run 205/1025
# Processing run 206/1025
# Processing run 207/1025
# Processing run 208/1025
# Processing run 209/1025
# Processing run 210/1025
# Processing run 211/1025
# Processing run 212/1025
# Processing run 213/1025
# Processing run 214/1025
# Processing run 215/1025
# Processing run 216/1025
# Processing run 217/1025
# Processing run 218/1025
# Processing run 219/1025
# Processing run 220/1025
# Processing run 221/1025
# Processing run 222/1025
# Processing run 223/1025
# Processing run 224/1025
# Processing run 225/1025
# Processing run 226/1025
# Processing run 227/1025
# Processing run 228/1025
# Processing run 229/1025
# Processing run 230/1025
# Processing run 231/1025
# Processing run 232/1025
# Processing run 233/1025
# Processing run 234/1025
# Processing run 235/1025
# Processing run 236/1025
# Processing run 237/1025
# Processing run 238/1025
# Processing run 239/1025
# Processing run 240/1025
# Processing run 241/1025
# Processing run 242/1025
# Processing run 243/1025
# Processing run 244/1025
# Processing run 245/1025
# Processing run 246/1025
# Processing run 247/1025
# Processing run 248/1025
# Processing run 249/1025
# Processing run 250/1025
# Processing run 251/1025
# Processing run 252/1025
# Processing run 253/1025
# Processing run 254/1025
# Processing run 255/1025
# Processing run 256/1025
# Processing run 257/1025
# Processing run 258/1025
# Processing run 259/1025
# Processing run 260/1025
# Processing run 261/1025
# Processing run 262/1025
# Processing run 263/1025
# Processing run 264/1025
# Processing run 265/1025
# Processing run 266/1025
# Processing run 267/1025
# Processing run 268/1025
# Processing run 269/1025
# Processing run 270/1025
# Processing run 271/1025
# Processing run 272/1025
# Processing run 273/1025
# Processing run 274/1025
# Processing run 275/1025
# Processing run 276/1025
# Processing run 277/1025
# Processing run 278/1025
# Processing run 279/1025
# Processing run 280/1025
# Processing run 281/1025
# Processing run 282/1025
# Processing run 283/1025
# Processing run 284/1025
# Processing run 285/1025
# Processing run 286/1025
# Processing run 287/1025
# Processing run 288/1025
# Processing run 289/1025
# Processing run 290/1025
# Processing run 291/1025
# Processing run 292/1025
# Processing run 293/1025
# Processing run 294/1025
# Processing run 295/1025
# Processing run 296/1025
# Processing run 297/1025
# Processing run 298/1025
# Processing run 299/1025
# Processing run 300/1025
# Processing run 301/1025
# Processing run 302/1025
# Processing run 303/1025
# Processing run 304/1025
# Processing run 305/1025
# Processing run 306/1025
# Processing run 307/1025
# Processing run 308/1025
# Processing run 309/1025
# Processing run 310/1025
# Processing run 311/1025
# Processing run 312/1025
# Processing run 313/1025
# Processing run 314/1025
# Processing run 315/1025
# Processing run 316/1025
# Processing run 317/1025
# Processing run 318/1025
# Processing run 319/1025
# Processing run 320/1025
# Processing run 321/1025
# Processing run 322/1025
# Processing run 323/1025
# Processing run 324/1025
# Processing run 325/1025
# Processing run 326/1025
# Processing run 327/1025
# Processing run 328/1025
# Processing run 329/1025
# Processing run 330/1025
# Processing run 331/1025
# Processing run 332/1025
# Processing run 333/1025
# Processing run 334/1025
# Processing run 335/1025
# Processing run 336/1025
# Processing run 337/1025
# Processing run 338/1025
# Processing run 339/1025
# Processing run 340/1025
# Processing run 341/1025
# Processing run 342/1025
# Processing run 343/1025
# Processing run 344/1025
# Processing run 345/1025
# Processing run 346/1025
# Processing run 347/1025
# Processing run 348/1025
# Processing run 349/1025
# Processing run 350/1025
# Processing run 351/1025
# Processing run 352/1025
# Processing run 353/1025
# Processing run 354/1025
# Processing run 355/1025
# Processing run 356/1025
# Processing run 357/1025
# Processing run 358/1025
# Processing run 359/1025
# Processing run 360/1025
# Processing run 361/1025
# Processing run 362/1025
# Processing run 363/1025
# Processing run 364/1025
# Processing run 365/1025
# Processing run 366/1025
# Processing run 367/1025
# Processing run 368/1025
# Processing run 369/1025
# Processing run 370/1025
# Processing run 371/1025
# Processing run 372/1025
# Processing run 373/1025
# Processing run 374/1025
# Processing run 375/1025
# Processing run 376/1025
# Processing run 377/1025
# Processing run 378/1025
# Processing run 379/1025
# Processing run 380/1025
# Processing run 381/1025
# Processing run 382/1025
# Processing run 383/1025
# Processing run 384/1025
# Processing run 385/1025
# Processing run 386/1025
# Processing run 387/1025
# Processing run 388/1025
# Processing run 389/1025
# Processing run 390/1025
# Processing run 391/1025
# Processing run 392/1025
# Processing run 393/1025
# Processing run 394/1025
# Processing run 395/1025
# Processing run 396/1025
# Processing run 397/1025
# Processing run 398/1025
# Processing run 399/1025
# Processing run 400/1025
# Processing run 401/1025
# Processing run 402/1025
# Processing run 403/1025
# Processing run 404/1025
# Processing run 405/1025
# Processing run 406/1025
# Processing run 407/1025
# Processing run 408/1025
# Processing run 409/1025
# Processing run 410/1025
# Processing run 411/1025
# Processing run 412/1025
# Processing run 413/1025
# Processing run 414/1025
# Processing run 415/1025
# Processing run 416/1025
# Processing run 417/1025
# Processing run 418/1025
# Processing run 419/1025
# Processing run 420/1025
# Processing run 421/1025
# Processing run 422/1025
# Processing run 423/1025
# Processing run 424/1025
# Processing run 425/1025
# Processing run 426/1025
# Processing run 427/1025
# Processing run 428/1025
# Processing run 429/1025
# Processing run 430/1025
# Processing run 431/1025
# Processing run 432/1025
# Processing run 433/1025
# Processing run 434/1025
# Processing run 435/1025
# Processing run 436/1025
# Processing run 437/1025
# Processing run 438/1025
# Processing run 439/1025
# Processing run 440/1025
# Processing run 441/1025
# Processing run 442/1025
# Processing run 443/1025
# Processing run 444/1025
# Processing run 445/1025
# Processing run 446/1025
# Processing run 447/1025
# Processing run 448/1025
# Processing run 449/1025
# Processing run 450/1025
# Processing run 451/1025
# Processing run 452/1025
# Processing run 453/1025
# Processing run 454/1025
# Processing run 455/1025
# Processing run 456/1025
# Processing run 457/1025
# Processing run 458/1025
# Processing run 459/1025
# Processing run 460/1025
# Processing run 461/1025
# Processing run 462/1025
# Processing run 463/1025
# Processing run 464/1025
# Processing run 465/1025
# Processing run 466/1025
# Processing run 467/1025
# Processing run 468/1025
# Processing run 469/1025
# Processing run 470/1025
# Processing run 471/1025
# Processing run 472/1025
# Processing run 473/1025
# Processing run 474/1025
# Processing run 475/1025
# Processing run 476/1025
# Processing run 477/1025
# Processing run 478/1025
# Processing run 479/1025
# Processing run 480/1025
# Processing run 481/1025
# Processing run 482/1025
# Processing run 483/1025
# Processing run 484/1025
# Processing run 485/1025
# Processing run 486/1025
# Processing run 487/1025
# Processing run 488/1025
# Processing run 489/1025
# Processing run 490/1025
# Processing run 491/1025
# Processing run 492/1025
# Processing run 493/1025
# Processing run 494/1025
# Processing run 495/1025
# Processing run 496/1025
# Processing run 497/1025
# Processing run 498/1025
# Processing run 499/1025
# Processing run 500/1025
# Processing run 501/1025
# Processing run 502/1025
# Processing run 503/1025
# Processing run 504/1025
# Processing run 505/1025
# Processing run 506/1025
# Processing run 507/1025
# Processing run 508/1025
# Processing run 509/1025
# Processing run 510/1025
# Processing run 511/1025
# Processing run 512/1025
# Processing run 513/1025
# Processing run 514/1025
# Processing run 515/1025
# Processing run 516/1025
# Processing run 517/1025
# Processing run 518/1025
# Processing run 519/1025
# Processing run 520/1025
# Processing run 521/1025
# Processing run 522/1025
# Processing run 523/1025
# Processing run 524/1025
# Processing run 525/1025
# Processing run 526/1025
# Processing run 527/1025
# Processing run 528/1025
# Processing run 529/1025
# Processing run 530/1025
# Processing run 531/1025
# Processing run 532/1025
# Processing run 533/1025
# Processing run 534/1025
# Processing run 535/1025
# Processing run 536/1025
# Processing run 537/1025
# Processing run 538/1025
# Processing run 539/1025
# Processing run 540/1025
# Processing run 541/1025
# Processing run 542/1025
# Processing run 543/1025
# Processing run 544/1025
# Processing run 545/1025
# Processing run 546/1025
# Processing run 547/1025
# Processing run 548/1025
# Processing run 549/1025
# Processing run 550/1025
# Processing run 551/1025
# Processing run 552/1025
# Processing run 553/1025
# Processing run 554/1025
# Processing run 555/1025
# Processing run 556/1025
# Processing run 557/1025
# Processing run 558/1025
# Processing run 559/1025
# Processing run 560/1025
# Processing run 561/1025
# Processing run 562/1025
# Processing run 563/1025
# Processing run 564/1025
# Processing run 565/1025
# Processing run 566/1025
# Processing run 567/1025
# Processing run 568/1025
# Processing run 569/1025
# Processing run 570/1025
# Processing run 571/1025
# Processing run 572/1025
# Processing run 573/1025
# Processing run 574/1025
# Processing run 575/1025
# Processing run 576/1025
# Processing run 577/1025
# Processing run 578/1025
# Processing run 579/1025
# Processing run 580/1025
# Processing run 581/1025
# Processing run 582/1025
# Processing run 583/1025
# Processing run 584/1025
# Processing run 585/1025
# Processing run 586/1025
# Processing run 587/1025
# Processing run 588/1025
# Processing run 589/1025
# Processing run 590/1025
# Processing run 591/1025
# Processing run 592/1025
# Processing run 593/1025
# Processing run 594/1025
# Processing run 595/1025
# Processing run 596/1025
# Processing run 597/1025
# Processing run 598/1025
# Processing run 599/1025
# Processing run 600/1025
# Processing run 601/1025
# Processing run 602/1025
# Processing run 603/1025
# Processing run 604/1025
# Processing run 605/1025
# Processing run 606/1025
# Processing run 607/1025
# Processing run 608/1025
# Processing run 609/1025
# Processing run 610/1025
# Processing run 611/1025
# Processing run 612/1025
# Processing run 613/1025
# Processing run 614/1025
# Processing run 615/1025
# Processing run 616/1025
# Processing run 617/1025
# Processing run 618/1025
# Processing run 619/1025
# Processing run 620/1025
# Processing run 621/1025
# Processing run 622/1025
# Processing run 623/1025
# Processing run 624/1025
# Processing run 625/1025
# Processing run 626/1025
# Processing run 627/1025
# Processing run 628/1025
# Processing run 629/1025
# Processing run 630/1025
# Processing run 631/1025
# Processing run 632/1025
# Processing run 633/1025
# Processing run 634/1025
# Processing run 635/1025
# Processing run 636/1025
# Processing run 637/1025
# Processing run 638/1025
# Processing run 639/1025
# Processing run 640/1025
# Processing run 641/1025
# Processing run 642/1025
# Processing run 643/1025
# Processing run 644/1025
# Processing run 645/1025
# Processing run 646/1025
# Processing run 647/1025
# Processing run 648/1025
# Processing run 649/1025
# Processing run 650/1025
# Processing run 651/1025
# Processing run 652/1025
# Processing run 653/1025
# Processing run 654/1025
# Processing run 655/1025
# Processing run 656/1025
# Processing run 657/1025
# Processing run 658/1025
# Processing run 659/1025
# Processing run 660/1025
# Processing run 661/1025
# Processing run 662/1025
# Processing run 663/1025
# Processing run 664/1025
# Processing run 665/1025
# Processing run 666/1025
# Processing run 667/1025
# Processing run 668/1025
# Processing run 669/1025
# Processing run 670/1025
# Processing run 671/1025
# Processing run 672/1025
# Processing run 673/1025
# Processing run 674/1025
# Processing run 675/1025
# Processing run 676/1025
# Processing run 677/1025
# Processing run 678/1025
# Processing run 679/1025
# Processing run 680/1025
# Processing run 681/1025
# Processing run 682/1025
# Processing run 683/1025
# Processing run 684/1025
# Processing run 685/1025
# Processing run 686/1025
# Processing run 687/1025
# Processing run 688/1025
# Processing run 689/1025
# Processing run 690/1025
# Processing run 691/1025
# Processing run 692/1025
# Processing run 693/1025
# Processing run 694/1025
# Processing run 695/1025
# Processing run 696/1025
# Processing run 697/1025
# Processing run 698/1025
# Processing run 699/1025
# Processing run 700/1025
# Processing run 701/1025
# Processing run 702/1025
# Processing run 703/1025
# Processing run 704/1025
# Processing run 705/1025
# Processing run 706/1025
# Processing run 707/1025
# Processing run 708/1025
# Processing run 709/1025
# Processing run 710/1025
# Processing run 711/1025
# Processing run 712/1025
# Processing run 713/1025
# Processing run 714/1025
# Processing run 715/1025
# Processing run 716/1025
# Processing run 717/1025
# Processing run 718/1025
# Processing run 719/1025
# Processing run 720/1025
# Processing run 721/1025
# Processing run 722/1025
# Processing run 723/1025
# Processing run 724/1025
# Processing run 725/1025
# Processing run 726/1025
# Processing run 727/1025
# Processing run 728/1025
# Processing run 729/1025
# Processing run 730/1025
# Processing run 731/1025
# Processing run 732/1025
# Processing run 733/1025
# Processing run 734/1025
# Processing run 735/1025
# Processing run 736/1025
# Processing run 737/1025
# Processing run 738/1025
# Processing run 739/1025
# Processing run 740/1025
# Processing run 741/1025
# Processing run 742/1025
# Processing run 743/1025
# Processing run 744/1025
# Processing run 745/1025
# Processing run 746/1025
# Processing run 747/1025
# Processing run 748/1025
# Processing run 749/1025
# Processing run 750/1025
# Processing run 751/1025
# Processing run 752/1025
# Processing run 753/1025
# Processing run 754/1025
# Processing run 755/1025
# Processing run 756/1025
# Processing run 757/1025
# Processing run 758/1025
# Processing run 759/1025
# Processing run 760/1025
# Processing run 761/1025
# Processing run 762/1025
# Processing run 763/1025
# Processing run 764/1025
# Processing run 765/1025
# Processing run 766/1025
# Processing run 767/1025
# Processing run 768/1025
# Processing run 769/1025
# Processing run 770/1025
# Processing run 771/1025
# Processing run 772/1025
# Processing run 773/1025
# Processing run 774/1025
# Processing run 775/1025
# Processing run 776/1025
# Processing run 777/1025
# Processing run 778/1025
# Processing run 779/1025
# Processing run 780/1025
# Processing run 781/1025
# Processing run 782/1025
# Processing run 783/1025
# Processing run 784/1025
# Processing run 785/1025
# Processing run 786/1025
# Processing run 787/1025
# Processing run 788/1025
# Processing run 789/1025
# Processing run 790/1025
# Processing run 791/1025
# Processing run 792/1025
# Processing run 793/1025
# Processing run 794/1025
# Processing run 795/1025
# Processing run 796/1025
# Processing run 797/1025
# Processing run 798/1025
# Processing run 799/1025
# Processing run 800/1025
# Processing run 801/1025
# Processing run 802/1025
# Processing run 803/1025
# Processing run 804/1025
# Processing run 805/1025
# Processing run 806/1025
# Processing run 807/1025
# Processing run 808/1025
# Processing run 809/1025
# Processing run 810/1025
# Processing run 811/1025
# Processing run 812/1025
# Processing run 813/1025
# Processing run 814/1025
# Processing run 815/1025
# Processing run 816/1025
# Processing run 817/1025
# Processing run 818/1025
# Processing run 819/1025
# Processing run 820/1025
# Processing run 821/1025
# Processing run 822/1025
# Processing run 823/1025
# Processing run 824/1025
# Processing run 825/1025
# Processing run 826/1025
# Processing run 827/1025
# Processing run 828/1025
# Processing run 829/1025
# Processing run 830/1025
# Processing run 831/1025
# Processing run 832/1025
# Processing run 833/1025
# Processing run 834/1025
# Processing run 835/1025
# Processing run 836/1025
# Processing run 837/1025
# Processing run 838/1025
# Processing run 839/1025
# Processing run 840/1025
# Processing run 841/1025
# Processing run 842/1025
# Processing run 843/1025
# Processing run 844/1025
# Processing run 845/1025
# Processing run 846/1025
# Processing run 847/1025
# Processing run 848/1025
# Processing run 849/1025
# Processing run 850/1025
# Processing run 851/1025
# Processing run 852/1025
# Processing run 853/1025
# Processing run 854/1025
# Processing run 855/1025
# Processing run 856/1025
# Processing run 857/1025
# Processing run 858/1025
# Processing run 859/1025
# Processing run 860/1025
# Processing run 861/1025
# Processing run 862/1025
# Processing run 863/1025
# Processing run 864/1025
# Processing run 865/1025
# Processing run 866/1025
# Processing run 867/1025
# Processing run 868/1025
# Processing run 869/1025
# Processing run 870/1025
# Processing run 871/1025
# Processing run 872/1025
# Processing run 873/1025
# Processing run 874/1025
# Processing run 875/1025
# Processing run 876/1025
# Processing run 877/1025
# Processing run 878/1025
# Processing run 879/1025
# Processing run 880/1025
# Processing run 881/1025
# Processing run 882/1025
# Processing run 883/1025
# Processing run 884/1025
# Processing run 885/1025
# Processing run 886/1025
# Processing run 887/1025
# Processing run 888/1025
# Processing run 889/1025
# Processing run 890/1025
# Processing run 891/1025
# Processing run 892/1025
# Processing run 893/1025
# Processing run 894/1025
# Processing run 895/1025
# Processing run 896/1025
# Processing run 897/1025
# Processing run 898/1025
# Processing run 899/1025
# Processing run 900/1025
# Processing run 901/1025
# Processing run 902/1025
# Processing run 903/1025
# Processing run 904/1025
# Processing run 905/1025
# Processing run 906/1025
# Processing run 907/1025
# Processing run 908/1025
# Processing run 909/1025
# Processing run 910/1025
# Processing run 911/1025
# Processing run 912/1025
# Processing run 913/1025
# Processing run 914/1025
# Processing run 915/1025
# Processing run 916/1025
# Processing run 917/1025
# Processing run 918/1025
# Processing run 919/1025
# Processing run 920/1025
# Processing run 921/1025
# Processing run 922/1025
# Processing run 923/1025
# Processing run 924/1025
# Processing run 925/1025
# Processing run 926/1025
# Processing run 927/1025
# Processing run 928/1025
# Processing run 929/1025
# Processing run 930/1025
# Processing run 931/1025
# Processing run 932/1025
# Processing run 933/1025
# Processing run 934/1025
# Processing run 935/1025
# Processing run 936/1025
# Processing run 937/1025
# Processing run 938/1025
# Processing run 939/1025
# Processing run 940/1025
# Processing run 941/1025
# Processing run 942/1025
# Processing run 943/1025
# Processing run 944/1025
# Processing run 945/1025
# Processing run 946/1025
# Processing run 947/1025
# Processing run 948/1025
# Processing run 949/1025
# Processing run 950/1025
# Processing run 951/1025
# Processing run 952/1025
# Processing run 953/1025
# Processing run 954/1025
# Processing run 955/1025
# Processing run 956/1025
# Processing run 957/1025
# Processing run 958/1025
# Processing run 959/1025
# Processing run 960/1025
# Processing run 961/1025
# Processing run 962/1025
# Processing run 963/1025
# Processing run 964/1025
# Processing run 965/1025
# Processing run 966/1025
# Processing run 967/1025
# Processing run 968/1025
# Processing run 969/1025
# Processing run 970/1025
# Processing run 971/1025
# Processing run 972/1025
# Processing run 973/1025
# Processing run 974/1025
# Processing run 975/1025
# Processing run 976/1025
# Processing run 977/1025
# Processing run 978/1025
# Processing run 979/1025
# Processing run 980/1025
# Processing run 981/1025
# Processing run 982/1025
# Processing run 983/1025
# Processing run 984/1025
# Processing run 985/1025
# Processing run 986/1025
# Processing run 987/1025
# Processing run 988/1025
# Processing run 989/1025
# Processing run 990/1025
# Processing run 991/1025
# Processing run 992/1025
# Processing run 993/1025
# Processing run 994/1025
# Processing run 995/1025
# Processing run 996/1025
# Processing run 997/1025
# Processing run 998/1025
# Processing run 999/1025
# Processing run 1000/1025
# Processing run 1001/1025
# Processing run 1002/1025
# Processing run 1003/1025
# Processing run 1004/1025
# Processing run 1005/1025
# Processing run 1006/1025
# Processing run 1007/1025
# Processing run 1008/1025
# Processing run 1009/1025
# Processing run 1010/1025
# Processing run 1011/1025
# Processing run 1012/1025
# Processing run 1013/1025
# Processing run 1014/1025
# Processing run 1015/1025
# Processing run 1016/1025
# Processing run 1017/1025
# Processing run 1018/1025
# Processing run 1019/1025
# Processing run 1020/1025
# Processing run 1021/1025
# Processing run 1022/1025
# Processing run 1023/1025
# Processing run 1024/1025
# Processing run 1025/1025
#     _step    best_y    _runtime    _timestamp  \
# 0     0.0  0.005652    5.096644  1.717454e+09
# 1     1.0  0.005652    5.096854  1.717454e+09
# 2     2.0  0.005652    5.096918  1.717454e+09
# 3     3.0  0.109855    5.096962  1.717454e+09
# 4     4.0  0.109855    5.097001  1.717454e+09
# ..    ...       ...         ...           ...
# 22   22.0  0.397120   71.843719  1.714474e+09
# 23   23.0  0.397120   72.870648  1.714474e+09
# 24   24.0  0.397120   73.766128  1.714474e+09
# 25   25.0  0.397120   74.689351  1.714474e+09
# 26   26.0  0.397120  164.201156  1.714474e+09
#
#                                                     x         y solver_name  \
# 0   [[C][O][C][=C][C][=C][C][=C][Ring1][Ring1][N][...  0.005652       turbo
# 1   [[C][C][C][C][C][Branch1][C][=C][C][C][C][Bran...  0.005321       turbo
# 2   [[C][C][=C][C][C][C][C][C][Branch2][Ring1][C][...  0.004442       turbo
# 3   [[C][=C][Branch1][=C][C][=C][C][=C][C][C][C][C...  0.109855       turbo
# 4   [[C][C][Branch1][C][C][C][C][Branch2][Branch2]...  0.000033       turbo
# ..                                                ...       ...         ...
# 22  [[=S@], [=S], [=PH2], [S-1], [F], [NH3+1], [#N...  0.397120      bounce
# 23  [[=S@], [=S], [=PH2], [S-1], [F], [NH3+1], [#N...  0.397120      bounce
# 24  [[=S@], [=S], [=PH2], [S-1], [F], [NH3+1], [#N...  0.397120      bounce
# 25  [[=S@], [=S], [=PH2], [S-1], [F], [NH3+1], [#N...  0.397120      bounce
# 26  [[=S@], [=S], [=PH2], [S-1], [F], [NH3+1], [#N...  0.397120      bounce
#
#      function_name  seed poli_hash hdbo_benchmark_hash poli_baselines_hash  \
# 0   amlodipine_mpo     1      None                None                None
# 1   amlodipine_mpo     1      None                None                None
# 2   amlodipine_mpo     1      None                None                None
# 3   amlodipine_mpo     1      None                None                None
# 4   amlodipine_mpo     1      None                None                None
# ..             ...   ...       ...                 ...                 ...
# 22       rdkit_qed   273      None                None                None
# 23       rdkit_qed   273      None                None                None
# 24       rdkit_qed   273      None                None                None
# 25       rdkit_qed   273      None                None                None
# 26       rdkit_qed   273      None                None                None
#
#        state
# 0   finished
# 1   finished
# 2   finished
# 3   finished
# 4   finished
# ..       ...
# 22   crashed
# 23   crashed
# 24   crashed
# 25   crashed
# 26   crashed
#
# [142527 rows x 13 columns]

# %%
solver_name_but_pretty = {
    "random_mutation": "HillClimbing",             # r"\texttt{HillClimbing}",
    # "cma_es": r"\texttt{CMAES}",
    "vanilla_bo_hvarfner": "Hvarfner's&nbsp;VanillaBO", # r"Hvarfner's \texttt{VanillaBO}",
    "line_bo": "RandomLineBO",                     # r"\texttt{RandomLineBO}",
    "saas_bo": "SAASBO",                           # r"\texttt{SAASBO}",
    # "alebo": r"\texttt{ALEBO}",
    # "turbo": r"\texttt{Turbo}",
    # "baxus": r"\texttt{BAxUS}",
    "bounce": "Bounce",                            # r"\texttt{Bounce}",
    "pr":     "ProbRep",                           # r"\texttt{ProbRep}",
}

def summary_per_function(
    df: pd.DataFrame,
    normalized_per_row: bool = True,
) -> tuple[pd.DataFrame, pd.DataFrame]:
    rows = []
    for function_name in df["function_name"].unique():
        for solver_name in df["solver_name"].unique():
            slice_df = df[
                (df["function_name"] == function_name)
                & (df["solver_name"] == solver_name)
            ]
            slice_df = slice_df[slice_df["seed"].isin([1, 2, 3])]
            if (
                len(slice_df["seed"].unique()) != 3
                and solver_name in solver_name_but_pretty.keys()
            ):
                # Only prints for one function (valsartan_smarts) in Bounce.
                # Should be fixed by Wednesday.
                print(
                    f"Something's fishy with {function_name} and {solver_name} ({slice_df['seed'].unique()})"
                )
            # assert len(slice_df["seed"].unique()) == 3
            best_y_per_seed = slice_df.groupby("seed")["y"].max()
            best_y = best_y_per_seed.mean()
            best_y_std = best_y_per_seed.std()
            rows.append(
                {
                    "function_name": function_name,
                    "solver_name": solver_name,
                    "average_best_y": best_y,
                    "std_best_y": best_y_std,
                }
            )

    summary = pd.DataFrame(rows)
    summary_avg = summary.pivot(
        index="function_name", columns="solver_name", values="average_best_y"
    )

    summary_std = summary.pivot(
        index="function_name", columns="solver_name", values="std_best_y"
    )

    # Normalize each row to be a percentage of the best value
    if normalized_per_row:
        for i, row in summary_avg.iterrows():
            best_value = row.max()
            if best_value == 0:
                continue
            summary_avg.loc[i] = row / best_value  # type: ignore

    return summary_avg, summary_std


def plot_heatmap(df, normalized: bool = True):
    summary_avg, _ = summary_per_function(df, normalized_per_row=normalized)

    # We keep the columns in solver_name_but_pretty order
    summary_avg = summary_avg[solver_name_but_pretty.keys()]

    # Rename columns to their pretty names
    summary_avg.columns = [solver_name_but_pretty[col] for col in summary_avg.columns]

    # Adjust the size of the figure to make squares smaller
    fig, ax = plt.subplots(1, 1, figsize=(17, 5))  # Adjust these numbers as needed

    # Capture the heatmap in a variable
    hmap = sns.heatmap(
        summary_avg.T,
        ax=ax,
        cmap="inferno",
        cbar_kws={"orientation": "vertical", "pad": 0.01},
    )

    # Modify the colorbar to only show min and max
    colorbar = hmap.collections[0].colorbar
    colorbar.set_ticks([colorbar.vmin, colorbar.vmax])
    colorbar.set_ticklabels(["min", "max"])

    ax.set_xlabel("")
    ax.set_ylabel("")

    plt.xticks(rotation=45, ha="right", rotation_mode="anchor")

    ax.set_title(
        f"Avg. Best Value ({n_dimensions}D latent space, 3 seeds, max. 10+100 function calls)"
        + "\n",
        fontsize=25,
    )
    fig.tight_layout()
    # fig.savefig(
    #     ROOT_DIR / "reports" / "figures" / f"table_as_heatmap_pmo_{n_dimensions}.jpg",
    #     dpi=300,
    #     bbox_inches="tight",
    # )
    plt.show()


def print_table(df, normalized: bool = False):
    summary_avg, summary_std = summary_per_function(df, normalized_per_row=normalized)

    final_table_rows: list[dict[str, str]] = []
    for function_name in summary_avg.index:
        row = {
            "Oracle": function_name#.replace("_", r"\_"),
        }
        for solver_name, pretty_solver_name in solver_name_but_pretty.items():
            if solver_name not in summary_avg.columns:
                row[pretty_solver_name] = r"\alert{[TBD]}"
                continue
            average = summary_avg.loc[function_name, solver_name]
            std = summary_std.loc[function_name, solver_name]

            if np.isnan(average):
                row[pretty_solver_name] = r"\alert{[TBD]}"
            else:
                avg = f"{average:.2f}"
                std = f"{std:.2f}" if not np.isnan(std) else r"\alert{?}"
                row[pretty_solver_name] = f"{avg}&nbsp;&plusmn;&nbsp;{std}"

        final_table_rows.append(row)

    final_table = pd.DataFrame(final_table_rows)
    final_table.set_index("Oracle", inplace=True)
    return final_table


n_dimensions = 2
normalized = True
tags = ["2024-06-02", "2024-06-01", "2024-05-31", "Old-PR-Results"]
tags: None = None
df = create_base_table(
    n_dimensions=n_dimensions, save_cache=False, use_cache=True, tags=tags
)
# plot_heatmap(df, normalized=normalized)
final_table = print_table(df, normalized=False)
final_table.to_csv("csv/benchmark_task.csv")
# Out:
# Something's fishy with osimetrinib_mpo and line_bo ([3 2])
# Something's fishy with rdkit_qed and line_bo ([2 1])
