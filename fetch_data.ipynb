# %%
import wandb 
import pandas as pd
from pathlib import Path
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

WANDB_PROJECT = "hdbo-embeddings-benchmark"
WANDB_ENTITY = "hdbo-benchmark"

matplotlib.rcParams.update({"text.usetex": True})
sns.set_theme(style="whitegrid", font_scale=1.75)

# %%
def get_all_runs_for_experiment(
    experiment_name: str,
    solver_name: str | None = None,
    function_name: str | None = None,
    n_dimensions: int | None = None,
    seed: int | None = None,
    tags: list[str] | None = None,
) -> list[wandb.apis.public.Run]:
    api = wandb.Api()

    filter_: dict[str, str | int | dict] = {
        "state": {"$in": ["finished", "running", "failed", "crashed"]},
    }
    if solver_name is not None:
        filter_["config.solver_name"] = solver_name

    if function_name is not None:
        filter_["config.function_name"] = function_name

    if n_dimensions is not None:
        # If it's a discrete solver, we don't need to filter by n_dimensions
        if solver_name in ["bounce", "pr"]:
            pass
        else:
            filter_["config.n_dimensions"] = n_dimensions

    if seed is not None:
        filter_["config.seed"] = seed

    if tags is not None:
        filter_["tags"] = {"$in": tags}

    runs = api.runs(
        f"{WANDB_ENTITY}/{experiment_name}",
        filter_ if filter_ else None,
    )
    return list(runs)

# %%
def convert_data_to_dataframes(
    all_data: list[wandb.apis.public.Run],
) -> list[pd.DataFrame]:
    dfs: list[pd.DataFrame] = []
    for i, run in enumerate(all_data):
        print(f"Processing run {i + 1}/{len(all_data)}")
        df = run.history()
        df["solver_name"] = run.config["solver_name"]
        df["function_name"] = run.config["function_name"]
        df["seed"] = run.config["seed"]
        df["poli_hash"] = run.config["poli_hash"]
        df["hdbo_benchmark_hash"] = run.config["hdbo_benchmark_hash"]
        df["poli_baselines_hash"] = run.config["poli_baselines_hash"]
        df["state"] = run.state
        dfs.append(df)

    return dfs


def create_base_table(
    n_dimensions: int = 128,
    save_cache: bool = True,
    use_cache: bool = False,
    tags: list[str] | None = None,
) -> pd.DataFrame:
    CACHE_PATH = Path("cache/results_cache")
    CACHE_PATH.mkdir(exist_ok=True, parents=True)
    tags_str = "-".join(tags) if tags is not None else "all"
    CACHE_FILE = (
        CACHE_PATH / f"base_table-n_dimensions-{n_dimensions}-tags-{tags_str}.csv"
    )

    if use_cache and CACHE_FILE.exists():
        df = pd.read_csv(CACHE_FILE)
        return df

    all_runs = get_all_runs_for_experiment(
        experiment_name="benchmark_on_pmo", n_dimensions=n_dimensions, tags=tags
    )

    # Append with the results from PR on 2D
    if n_dimensions != 2:
        pr_runs = get_all_runs_for_experiment(
            experiment_name="benchmark_on_pmo",
            solver_name="pr",
            n_dimensions=2,
            tags=tags,
        )
        all_runs.extend(pr_runs)

    # Append the results of Bounce on 128D
    if n_dimensions != 128:
        bounce_runs = get_all_runs_for_experiment(
            experiment_name="benchmark_on_pmo",
            solver_name="bounce",
            n_dimensions=128,
            tags=tags,
        )
        all_runs.extend(bounce_runs)

    all_dfs = convert_data_to_dataframes(all_runs)

    df = pd.concat(all_dfs)
    if save_cache:
        df.to_csv(CACHE_FILE, index=False)

    return df

if __name__ == "__main__":
    # df = create_base_table(
    #     n_dimensions=2,
    #     save_cache=True,
    #     use_cache=False,
    #     tags=None,
    # )
    # print(df)

    df = create_base_table(
        n_dimensions=128,
        save_cache=True,
        use_cache=False,
        tags=None,
    )
    print(df)
# Out:
# Processing run 1/1311
# Processing run 2/1311
# Processing run 3/1311
# Processing run 4/1311
# Processing run 5/1311
# Processing run 6/1311
# Processing run 7/1311
# Processing run 8/1311
# Processing run 9/1311
# Processing run 10/1311
# Processing run 11/1311
# Processing run 12/1311
# Processing run 13/1311
# Processing run 14/1311
# Processing run 15/1311
# Processing run 16/1311
# Processing run 17/1311
# Processing run 18/1311
# Processing run 19/1311
# Processing run 20/1311
# Processing run 21/1311
# Processing run 22/1311
# Processing run 23/1311
# Processing run 24/1311
# Processing run 25/1311
# Processing run 26/1311
# Processing run 27/1311
# Processing run 28/1311
# Processing run 29/1311
# Processing run 30/1311
# Processing run 31/1311
# Processing run 32/1311
# Processing run 33/1311
# Processing run 34/1311
# Processing run 35/1311
# Processing run 36/1311
# Processing run 37/1311
# Processing run 38/1311
# Processing run 39/1311
# Processing run 40/1311
# Processing run 41/1311
# Processing run 42/1311
# Processing run 43/1311
# Processing run 44/1311
# Processing run 45/1311
# Processing run 46/1311
# Processing run 47/1311
# Processing run 48/1311
# Processing run 49/1311
# Processing run 50/1311
# Processing run 51/1311
# Processing run 52/1311
# Processing run 53/1311
# Processing run 54/1311
# Processing run 55/1311
# Processing run 56/1311
# Processing run 57/1311
# Processing run 58/1311
# Processing run 59/1311
# Processing run 60/1311
# Processing run 61/1311
# Processing run 62/1311
# Processing run 63/1311
# Processing run 64/1311
# Processing run 65/1311
# Processing run 66/1311
# Processing run 67/1311
# Processing run 68/1311
# Processing run 69/1311
# Processing run 70/1311
# Processing run 71/1311
# Processing run 72/1311
# Processing run 73/1311
# Processing run 74/1311
# Processing run 75/1311
# Processing run 76/1311
# Processing run 77/1311
# Processing run 78/1311
# Processing run 79/1311
# Processing run 80/1311
# Processing run 81/1311
# Processing run 82/1311
# Processing run 83/1311
# Processing run 84/1311
# Processing run 85/1311
# Processing run 86/1311
# Processing run 87/1311
# Processing run 88/1311
# Processing run 89/1311
# Processing run 90/1311
# Processing run 91/1311
# Processing run 92/1311
# Processing run 93/1311
# Processing run 94/1311
# Processing run 95/1311
# Processing run 96/1311
# Processing run 97/1311
# Processing run 98/1311
# Processing run 99/1311
# Processing run 100/1311
# Processing run 101/1311
# Processing run 102/1311
# Processing run 103/1311
# Processing run 104/1311
# Processing run 105/1311
# Processing run 106/1311
# Processing run 107/1311
# Processing run 108/1311
# Processing run 109/1311
# Processing run 110/1311
# Processing run 111/1311
# Processing run 112/1311
# Processing run 113/1311
# Processing run 114/1311
# Processing run 115/1311
# Processing run 116/1311
# Processing run 117/1311
# Processing run 118/1311
# Processing run 119/1311
# Processing run 120/1311
# Processing run 121/1311
# Processing run 122/1311
# Processing run 123/1311
# Processing run 124/1311
# Processing run 125/1311
# Processing run 126/1311
# Processing run 127/1311
# Processing run 128/1311
# Processing run 129/1311
# Processing run 130/1311
# Processing run 131/1311
# Processing run 132/1311
# Processing run 133/1311
# Processing run 134/1311
# Processing run 1242/1311
# Processing run 1243/1311
# Processing run 1244/1311
# Processing run 1245/1311
# Processing run 1246/1311
# Processing run 1247/1311
# Processing run 1248/1311
# Processing run 1249/1311
# Processing run 1250/1311
# Processing run 1251/1311
# Processing run 1252/1311
# Processing run 1253/1311
# Processing run 1254/1311
# Processing run 1255/1311
# Processing run 1256/1311
# Processing run 1257/1311
# Processing run 1258/1311
# Processing run 1259/1311
# Processing run 1260/1311
# Processing run 1261/1311
# Processing run 1262/1311
# Processing run 1263/1311
# Processing run 1264/1311
# Processing run 1265/1311
# Processing run 1266/1311
# Processing run 1267/1311
# Processing run 1268/1311
# Processing run 1269/1311
# Processing run 1270/1311
# Processing run 1271/1311
# Processing run 1272/1311
# Processing run 1273/1311
# Processing run 1274/1311
# Processing run 1275/1311
# Processing run 1276/1311
# Processing run 1277/1311
# Processing run 1278/1311
# Processing run 1279/1311
# Processing run 1280/1311
# Processing run 1281/1311
# Processing run 1282/1311
# Processing run 1283/1311
# Processing run 1284/1311
# Processing run 1285/1311
# Processing run 1286/1311
# Processing run 1287/1311
# Processing run 1288/1311
# Processing run 1289/1311
# Processing run 1290/1311
# Processing run 1291/1311
# Processing run 1292/1311
# Processing run 1293/1311
# Processing run 1294/1311
# Processing run 1295/1311
# Processing run 1296/1311
# Processing run 1297/1311
# Processing run 1298/1311
# Processing run 1299/1311
# Processing run 1300/1311
# Processing run 1301/1311
# Processing run 1302/1311
# Processing run 1303/1311
# Processing run 1304/1311
# Processing run 1305/1311
# Processing run 1306/1311
# Processing run 1307/1311
# Processing run 1308/1311
# Processing run 1309/1311
# Processing run 1310/1311
# Processing run 1311/1311

# %%
solver_name_but_pretty = {
    "random_mutation": "HillClimbing",             # r"\texttt{HillClimbing}",
    # "cma_es": r"\texttt{CMAES}",
    "vanilla_bo_hvarfner": "Hvarfner's&nbsp;VanillaBO", # r"Hvarfner's \texttt{VanillaBO}",
    "line_bo": "RandomLineBO",                     # r"\texttt{RandomLineBO}",
    "saas_bo": "SAASBO",                           # r"\texttt{SAASBO}",
    # "alebo": r"\texttt{ALEBO}",
    # "turbo": r"\texttt{Turbo}",
    # "baxus": r"\texttt{BAxUS}",
    "bounce": "Bounce",                            # r"\texttt{Bounce}",
    "pr":     "ProbRep",                           # r"\texttt{ProbRep}",
}

def summary_per_function(
    df: pd.DataFrame,
    normalized_per_row: bool = True,
) -> tuple[pd.DataFrame, pd.DataFrame]:
    rows = []
    for function_name in df["function_name"].unique():
        for solver_name in df["solver_name"].unique():
            slice_df = df[
                (df["function_name"] == function_name)
                & (df["solver_name"] == solver_name)
            ]
            slice_df = slice_df[slice_df["seed"].isin([1, 2, 3])]
            if (
                len(slice_df["seed"].unique()) != 3
                and solver_name in solver_name_but_pretty.keys()
            ):
                # Only prints for one function (valsartan_smarts) in Bounce.
                # Should be fixed by Wednesday.
                print(
                    f"Something's fishy with {function_name} and {solver_name} ({slice_df['seed'].unique()})"
                )
            # assert len(slice_df["seed"].unique()) == 3
            best_y_per_seed = slice_df.groupby("seed")["y"].max()
            best_y = best_y_per_seed.mean()
            best_y_std = best_y_per_seed.std()
            rows.append(
                {
                    "function_name": function_name,
                    "solver_name": solver_name,
                    "average_best_y": best_y,
                    "std_best_y": best_y_std,
                }
            )

    summary = pd.DataFrame(rows)
    summary_avg = summary.pivot(
        index="function_name", columns="solver_name", values="average_best_y"
    )

    summary_std = summary.pivot(
        index="function_name", columns="solver_name", values="std_best_y"
    )

    # Normalize each row to be a percentage of the best value
    if normalized_per_row:
        for i, row in summary_avg.iterrows():
            best_value = row.max()
            if best_value == 0:
                continue
            summary_avg.loc[i] = row / best_value  # type: ignore

    return summary_avg, summary_std


def plot_heatmap(df, n_dimensions, normalized: bool = True):
    summary_avg, _ = summary_per_function(df, normalized_per_row=normalized)

    # We keep the columns in solver_name_but_pretty order
    summary_avg = summary_avg[solver_name_but_pretty.keys()]

    # Rename columns to their pretty names
    summary_avg.columns = [solver_name_but_pretty[col] for col in summary_avg.columns]

    # Adjust the size of the figure to make squares smaller
    fig, ax = plt.subplots(1, 1, figsize=(17, 5))  # Adjust these numbers as needed

    # Capture the heatmap in a variable
    hmap = sns.heatmap(
        summary_avg.T,
        ax=ax,
        cmap="inferno",
        cbar_kws={"orientation": "vertical", "pad": 0.01},
    )

    # Modify the colorbar to only show min and max
    colorbar = hmap.collections[0].colorbar
    colorbar.set_ticks([colorbar.vmin, colorbar.vmax])
    colorbar.set_ticklabels(["min", "max"])

    ax.set_xlabel("")
    ax.set_ylabel("")

    plt.xticks(rotation=45, ha="right", rotation_mode="anchor")

    ax.set_title(
        f"Avg. Best Value ({n_dimensions}D latent space, 3 seeds, max. 10+100 function calls)"
        + "\n",
        fontsize=25,
    )
    fig.tight_layout()
    # fig.savefig(
    #     ROOT_DIR / "reports" / "figures" / f"table_as_heatmap_pmo_{n_dimensions}.jpg",
    #     dpi=300,
    #     bbox_inches="tight",
    # )
    plt.show()


def print_table(df, normalized: bool = False):
    summary_avg, summary_std = summary_per_function(df, normalized_per_row=normalized)

    final_table_rows: list[dict[str, str]] = []
    for function_name in summary_avg.index:
        row = {
            "Oracle": function_name#.replace("_", r"\_"),
        }
        for solver_name, pretty_solver_name in solver_name_but_pretty.items():
            if solver_name not in summary_avg.columns:
                row[pretty_solver_name] = "TBD" #r"\alert{[TBD]}"
                continue
            average = summary_avg.loc[function_name, solver_name]
            std = summary_std.loc[function_name, solver_name]

            if np.isnan(average):
                row[pretty_solver_name] = "TBD" #r"\alert{[TBD]}"
            else:
                avg = f"{average:.2f}"
                std = f"{std:.2f}" if not np.isnan(std) else r"\alert{?}"
                row[pretty_solver_name] = f"{avg}&nbsp;&plusmn;&nbsp;{std}"

        final_table_rows.append(row)

    final_table = pd.DataFrame(final_table_rows)
    final_table.set_index("Oracle", inplace=True)
    return final_table

# %%
# tags = ["2024-06-02", "2024-06-01", "2024-05-31", "Old-PR-Results"]
# tags: None = None

# 2D case
df = create_base_table(
    n_dimensions=2, save_cache=False, use_cache=True, tags=None
)

# plot_heatmap(df, n_dimensions=n_dimensions, normalized=True)
final_table_2d = print_table(df, normalized=False)
final_table_2d.to_csv("csv/benchmark_task_2d.csv")

# 128 D case
df = create_base_table(
    n_dimensions=128, save_cache=False, use_cache=True, tags=None
)

# plot_heatmap(df, n_dimensions=n_dimensions, normalized=True)
final_table_128d = print_table(df, normalized=False)
final_table_128d.to_csv("csv/benchmark_task_128d.csv")
# Out:
# Something's fishy with osimetrinib_mpo and line_bo ([3 2])
# Something's fishy with rdkit_qed and line_bo ([2 1])
# Processing run 1/1311
# Processing run 2/1311
# Processing run 3/1311
# Processing run 4/1311
# Processing run 5/1311
# Processing run 6/1311
# Processing run 7/1311
# Processing run 8/1311
# Processing run 9/1311
# Processing run 10/1311
# Processing run 11/1311
# Processing run 12/1311
# Processing run 13/1311
# Processing run 14/1311
# Processing run 15/1311
# Processing run 16/1311
# Processing run 17/1311
# Processing run 18/1311
# Processing run 19/1311
# Processing run 20/1311
# Processing run 21/1311
# Processing run 22/1311
# Processing run 23/1311
# Processing run 24/1311
# Processing run 25/1311
# Processing run 26/1311
# Processing run 27/1311
# Processing run 28/1311
# Processing run 29/1311
# Processing run 30/1311
# Processing run 31/1311
# Processing run 32/1311
# Processing run 33/1311
# Processing run 34/1311
# Processing run 35/1311
# Processing run 36/1311
# Processing run 37/1311
# Processing run 38/1311
# Processing run 39/1311
# Processing run 40/1311
# Processing run 41/1311
# Processing run 42/1311
# Processing run 43/1311
# Processing run 44/1311
# Processing run 45/1311
# Processing run 46/1311
# Processing run 47/1311
# Processing run 48/1311
# Processing run 49/1311
# Processing run 50/1311
# Processing run 51/1311
# Processing run 52/1311
# Processing run 53/1311
# Processing run 54/1311
# Processing run 55/1311
# Processing run 56/1311
# Processing run 57/1311
# Processing run 58/1311
# Processing run 59/1311
# Processing run 60/1311
# Processing run 61/1311
# Processing run 62/1311
# Processing run 63/1311
# Processing run 64/1311
# Processing run 65/1311
# Processing run 66/1311
# Processing run 67/1311
# Processing run 68/1311
# Processing run 69/1311
# Processing run 70/1311
# Processing run 71/1311
# Processing run 72/1311
# Processing run 73/1311
# Processing run 74/1311
# Processing run 75/1311
# Processing run 76/1311
# Processing run 77/1311
# Processing run 78/1311
# Processing run 79/1311
# Processing run 80/1311
# Processing run 81/1311
# Processing run 82/1311
# Processing run 83/1311
# Processing run 84/1311
# Processing run 85/1311
# Processing run 86/1311
# Processing run 87/1311
# Processing run 88/1311
# Processing run 89/1311
# Processing run 90/1311
# Processing run 91/1311
# Processing run 92/1311
# Processing run 93/1311
# Processing run 94/1311
# Processing run 95/1311
# Processing run 96/1311
# Processing run 97/1311
# Processing run 98/1311
# Processing run 99/1311
# Processing run 100/1311
# Processing run 101/1311
# Processing run 102/1311
# Processing run 103/1311
# Processing run 104/1311
# Processing run 105/1311
# Processing run 106/1311
# Processing run 107/1311
# Processing run 108/1311
# Processing run 109/1311
# Processing run 110/1311
# Processing run 111/1311
# Processing run 112/1311
# Processing run 113/1311
# Processing run 114/1311
# Processing run 115/1311
# Processing run 116/1311
# Processing run 117/1311
# Processing run 118/1311
# Processing run 119/1311
# Processing run 120/1311
# Processing run 121/1311
# Processing run 686/1311
# Processing run 687/1311
# Processing run 688/1311
# Processing run 689/1311
# Processing run 690/1311
# Processing run 691/1311
# Processing run 692/1311
# Processing run 693/1311
# Processing run 694/1311
# Processing run 695/1311
# Processing run 696/1311
# Processing run 697/1311
# Processing run 698/1311
# Processing run 699/1311
# Processing run 700/1311
# Processing run 701/1311
# Processing run 702/1311
# Processing run 703/1311
# Processing run 704/1311
# Processing run 705/1311
# Processing run 706/1311
# Processing run 707/1311
# Processing run 708/1311
# Processing run 709/1311
# Processing run 710/1311
# Processing run 711/1311
# Processing run 712/1311
# Processing run 713/1311
# Processing run 714/1311
# Processing run 715/1311
# Processing run 716/1311
# Processing run 717/1311
# Processing run 718/1311
# Processing run 719/1311
# Processing run 720/1311
# Processing run 721/1311
# Processing run 722/1311
# Processing run 723/1311
# Processing run 724/1311
# Processing run 725/1311
# Processing run 726/1311
# Processing run 727/1311
# Processing run 728/1311
# Processing run 729/1311
# Processing run 730/1311
# Processing run 731/1311
# Processing run 732/1311
# Processing run 733/1311
# Processing run 734/1311
# Processing run 735/1311
# Processing run 736/1311
# Processing run 737/1311
# Processing run 738/1311
# Processing run 739/1311
# Processing run 740/1311
# Processing run 741/1311
# Processing run 742/1311
# Processing run 743/1311
# Processing run 744/1311
# Processing run 745/1311
# Processing run 746/1311
# Processing run 747/1311
# Processing run 748/1311
# Processing run 749/1311
# Processing run 750/1311
# Processing run 751/1311
# Processing run 752/1311
# Processing run 753/1311
# Processing run 754/1311
# Processing run 755/1311
# Processing run 756/1311
# Processing run 757/1311
# Processing run 758/1311
# Processing run 759/1311
# Processing run 760/1311
# Processing run 761/1311
# Processing run 762/1311
# Processing run 763/1311
# Processing run 764/1311
# Processing run 765/1311
# Processing run 766/1311
# Processing run 767/1311
# Processing run 768/1311
# Processing run 769/1311
# Processing run 770/1311
# Processing run 771/1311
# Processing run 772/1311
# Processing run 773/1311
# Processing run 774/1311
# Processing run 775/1311
# Processing run 776/1311
# Processing run 777/1311
# Processing run 778/1311
# Processing run 779/1311
# Processing run 780/1311
# Processing run 781/1311
# Processing run 782/1311
# Processing run 783/1311
# Processing run 784/1311
# Processing run 785/1311
# Processing run 786/1311
# Processing run 787/1311
# Processing run 788/1311
# Processing run 789/1311
# Processing run 790/1311
# Processing run 791/1311
# Processing run 792/1311
# Processing run 793/1311
# Processing run 794/1311
# Processing run 795/1311
# Processing run 796/1311
# Processing run 797/1311
# Processing run 798/1311
# Processing run 799/1311
# Processing run 800/1311
# Processing run 801/1311
# Processing run 802/1311
# Processing run 803/1311
# Processing run 804/1311
# Processing run 805/1311
# Processing run 806/1311
# Processing run 807/1311
# Processing run 808/1311
# Processing run 809/1311
# Processing run 810/1311
# Processing run 811/1311
# Processing run 812/1311
# Processing run 813/1311
# Processing run 814/1311
# Processing run 815/1311
# Processing run 816/1311
# Processing run 817/1311
# Processing run 818/1311
# Processing run 819/1311
# Processing run 820/1311
# Processing run 821/1311
# Processing run 822/1311
# Processing run 823/1311
# Processing run 824/1311
# Processing run 825/1311
# Processing run 826/1311
# Processing run 827/1311
# Processing run 969/1311
# Processing run 970/1311
# Processing run 971/1311
# Processing run 972/1311
# Processing run 973/1311
# Processing run 974/1311
# Processing run 975/1311
# Processing run 976/1311
# Processing run 977/1311
# Processing run 978/1311
# Processing run 979/1311
# Processing run 980/1311
# Processing run 981/1311
# Processing run 982/1311
# Processing run 983/1311
# Processing run 984/1311
# Processing run 985/1311
# Processing run 986/1311
# Processing run 987/1311
# Processing run 988/1311
# Processing run 989/1311
# Processing run 990/1311
# Processing run 991/1311
# Processing run 992/1311
# Processing run 993/1311
# Processing run 994/1311
# Processing run 995/1311
# Processing run 996/1311
# Processing run 997/1311
# Processing run 998/1311
# Processing run 999/1311
# Processing run 1000/1311
# Processing run 1001/1311
# Processing run 1002/1311
# Processing run 1003/1311
# Processing run 1004/1311
# Processing run 1005/1311
# Processing run 1006/1311
# Processing run 1007/1311
# Processing run 1008/1311
# Processing run 1009/1311
# Processing run 1010/1311
# Processing run 1011/1311
# Processing run 1012/1311
# Processing run 1013/1311
# Processing run 1014/1311
# Processing run 1015/1311
# Processing run 1016/1311
# Processing run 1017/1311
# Processing run 1018/1311
# Processing run 1019/1311
# Processing run 1020/1311
# Processing run 1021/1311
# Processing run 1022/1311
# Processing run 1023/1311
# Processing run 1024/1311
# Processing run 1025/1311
# Processing run 1026/1311
# Processing run 1027/1311
# Processing run 1028/1311
# Processing run 1029/1311
# Processing run 1030/1311
# Processing run 1031/1311
# Processing run 1032/1311
# Processing run 1033/1311
# Processing run 1034/1311
# Processing run 1035/1311
# Processing run 1036/1311
# Processing run 1037/1311
# Processing run 1038/1311
# Processing run 1039/1311
# Processing run 1040/1311
# Processing run 1041/1311
# Processing run 1042/1311
# Processing run 1043/1311
# Processing run 1044/1311
# Processing run 1045/1311
# Processing run 1046/1311
# Processing run 1047/1311
# Processing run 1048/1311
# Processing run 1049/1311
# Processing run 1050/1311
# Processing run 1051/1311
# Processing run 1052/1311
# Processing run 1053/1311
# Processing run 1054/1311
# Processing run 1055/1311
# Processing run 1056/1311
# Processing run 1057/1311
# Processing run 1058/1311
# Processing run 1059/1311
# Processing run 1060/1311
# Processing run 1061/1311
# Processing run 1062/1311
# Processing run 1063/1311
# Processing run 1064/1311
# Processing run 1065/1311
# Processing run 1066/1311
# Processing run 1067/1311
# Processing run 1068/1311
# Processing run 1069/1311
# Processing run 1070/1311
# Processing run 1071/1311
# Processing run 1072/1311
# Processing run 1073/1311
# Processing run 1074/1311
# Processing run 1075/1311
# Processing run 1076/1311
# Processing run 1077/1311
# Processing run 1078/1311
# Processing run 1079/1311
# Processing run 1080/1311
# Processing run 1081/1311
# Processing run 1082/1311
# Processing run 1083/1311
# Processing run 1084/1311
# Processing run 1085/1311
# Processing run 1086/1311
# Processing run 1087/1311
# Processing run 1088/1311
# Processing run 1089/1311
# Processing run 1090/1311
# Processing run 1091/1311
# Processing run 1092/1311
# Processing run 1093/1311
# Processing run 1094/1311
# Processing run 1095/1311
# Processing run 1096/1311
# Processing run 1097/1311
# Processing run 1098/1311
# Processing run 1099/1311
# Processing run 1100/1311
# Processing run 1101/1311
# Processing run 1102/1311
# Processing run 1103/1311
# Processing run 1104/1311
# Processing run 1105/1311
# Processing run 1106/1311
# Processing run 1107/1311
# Processing run 1108/1311
# Processing run 1109/1311
# Processing run 1110/1311
# Processing run 1111/1311
# Processing run 1112/1311
# Processing run 1113/1311
# Processing run 1114/1311
# Processing run 1115/1311
# Processing run 1116/1311
# Processing run 1117/1311
# Processing run 1118/1311
# Processing run 1119/1311
# Processing run 1120/1311
# Processing run 1121/1311
# Processing run 1122/1311
# Processing run 1123/1311
# Processing run 1124/1311
# Processing run 1125/1311
# Processing run 1126/1311
# Processing run 1127/1311
# Processing run 1128/1311
# Processing run 1129/1311
# Processing run 1130/1311
# Processing run 1131/1311
# Processing run 1132/1311
# Processing run 1133/1311
# Processing run 1134/1311
# Processing run 1135/1311
# Processing run 1136/1311
# Processing run 1137/1311
# Processing run 1138/1311
# Processing run 1139/1311
# Processing run 1140/1311
# Processing run 1141/1311
# Processing run 1142/1311
# Processing run 1143/1311
# Processing run 1144/1311
# Processing run 1145/1311
# Processing run 1146/1311
# Processing run 1147/1311
# Processing run 1148/1311
# Processing run 1149/1311
# Processing run 1150/1311
# Processing run 1151/1311
# Processing run 1152/1311
# Processing run 1153/1311
# Processing run 1154/1311
# Processing run 1155/1311
# Processing run 1156/1311
# Processing run 1157/1311
# Processing run 1158/1311
# Processing run 1159/1311
# Processing run 1160/1311
# Processing run 1161/1311
# Processing run 1162/1311
# Processing run 1163/1311
# Processing run 1164/1311
# Processing run 1165/1311
# Processing run 1166/1311
# Processing run 1167/1311
# Processing run 1168/1311
# Processing run 1169/1311
# Processing run 1170/1311
# Processing run 1171/1311
# Processing run 1172/1311
# Processing run 1173/1311
# Processing run 1174/1311
# Processing run 1175/1311
# Processing run 1176/1311
# Processing run 1177/1311
# Processing run 1178/1311
# Processing run 1179/1311
# Processing run 1180/1311
# Processing run 1181/1311
# Processing run 1182/1311
# Processing run 1183/1311
# Processing run 1184/1311
# Processing run 1185/1311
# Processing run 1186/1311
# Processing run 1187/1311
# Processing run 1188/1311
# Processing run 1189/1311
# Processing run 1190/1311
# Processing run 1191/1311
# Processing run 1192/1311
# Processing run 1193/1311
# Processing run 1194/1311
# Processing run 1195/1311
# Processing run 1196/1311
# Processing run 1197/1311
# Processing run 1198/1311
# Processing run 1199/1311
# Processing run 1200/1311
# Processing run 1201/1311
# Processing run 1202/1311
# Processing run 1203/1311
# Processing run 1204/1311
# Processing run 1205/1311
# Processing run 1206/1311
# Processing run 1207/1311
# Processing run 1208/1311
# Processing run 1209/1311
# Processing run 1210/1311
# Processing run 1211/1311
# Processing run 1212/1311
# Processing run 1213/1311
# Processing run 1214/1311
# Processing run 1215/1311
# Processing run 1216/1311
# Processing run 1217/1311
# Processing run 1218/1311
# Processing run 1219/1311
# Processing run 1220/1311
# Processing run 1221/1311
# Processing run 1222/1311
# Processing run 1223/1311
# Processing run 1224/1311
# Processing run 1225/1311
# Processing run 1226/1311
# Processing run 1227/1311
# Processing run 1228/1311
# Processing run 1229/1311
# Processing run 1230/1311
# Processing run 1231/1311
# Processing run 1232/1311
# Processing run 1233/1311
# Processing run 1234/1311
# Processing run 1235/1311
# Processing run 1236/1311
# Processing run 1237/1311
# Processing run 1238/1311
# Processing run 1239/1311
# Processing run 1240/1311
# Processing run 1241/1311
# Processing run 1242/1311
# Processing run 1243/1311
# Processing run 1244/1311
# Processing run 1245/1311
# Processing run 1246/1311
# Processing run 1247/1311
# Processing run 1248/1311
# Processing run 1249/1311
# Processing run 1250/1311
# Processing run 1251/1311
# Processing run 1252/1311
# Processing run 1253/1311
# Processing run 1254/1311
# Processing run 1255/1311
# Processing run 1256/1311
# Processing run 1257/1311
# Processing run 1258/1311
# Processing run 1259/1311
# Processing run 1260/1311
# Processing run 1261/1311
# Processing run 1262/1311
# Processing run 1263/1311
# Processing run 1264/1311
# Processing run 1265/1311
# Processing run 1266/1311
# Processing run 1267/1311
# Processing run 1268/1311
# Processing run 1269/1311
# Processing run 1270/1311
# Processing run 1271/1311
# Processing run 1272/1311
# Processing run 1273/1311
# wandb: WARNING A graphql request initiated by the public wandb API timed out (timeout=19 sec). Create a new API with an integer timeout larger than 19, e.g., `api = wandb.Api(timeout=29)` to increase the graphql timeout.
# Processing run 1274/1311
# Processing run 1275/1311
# Processing run 1276/1311
# Processing run 1277/1311
# Processing run 1278/1311
# Processing run 1279/1311
# Processing run 1280/1311
# Processing run 1281/1311
# Processing run 1282/1311
# Processing run 1283/1311
# Processing run 1284/1311
# Processing run 1285/1311
# Processing run 1286/1311
# Processing run 1287/1311
# Processing run 1288/1311
# Processing run 1289/1311
# Processing run 1290/1311
# Processing run 1291/1311
# Processing run 1292/1311
# Processing run 1293/1311
# Processing run 1294/1311
# Processing run 1295/1311
# Processing run 1296/1311
# Processing run 1297/1311
# Processing run 1298/1311
# Processing run 1299/1311
# Processing run 1300/1311
# Processing run 1301/1311
# Processing run 1302/1311
# Processing run 1303/1311
# Processing run 1304/1311
# Processing run 1305/1311
# Processing run 1306/1311
# Processing run 1307/1311
# Processing run 1308/1311
# Processing run 1309/1311
# Processing run 1310/1311
# Processing run 1311/1311
# Something's fishy with valsartan_smarts and saas_bo ([2 1])
# Something's fishy with deco_hop and saas_bo ([])
# Something's fishy with fexofenadine_mpo and saas_bo ([])
# Something's fishy with isomer_c9h10n2o2pf2cl and saas_bo ([])
# Something's fishy with median_1 and saas_bo ([])
# Something's fishy with isomer_c7h8n2o2 and saas_bo ([])
# Something's fishy with median_2 and saas_bo ([])
# Something's fishy with mestranol_similarity and saas_bo ([])
# Something's fishy with osimetrinib_mpo and saas_bo ([])
# Something's fishy with perindopril_mpo and saas_bo ([])
# Something's fishy with ranolazine_mpo and saas_bo ([])
# Something's fishy with rdkit_logp and saas_bo ([])
# Something's fishy with rdkit_qed and saas_bo ([])
# Something's fishy with sa_tdc and saas_bo ([])
# Something's fishy with scaffold_hop and saas_bo ([])
# Something's fishy with sitagliptin_mpo and saas_bo ([])
# Something's fishy with thiothixene_rediscovery and saas_bo ([])
# Something's fishy with troglitazone_rediscovery and saas_bo ([])
